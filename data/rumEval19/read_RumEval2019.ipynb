# %% [markdown]
# # Parse RumEval Twitter data

# %%
import os
import numpy as np
import pandas as pd
import pickle as pc
import dateutil.parser
from glob import glob
import json
import codecs

from nltk.tokenize.api import StringTokenizer
from nltk.tokenize import TweetTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE

# %%
import matplotlib.pyplot as plt

# Set font size
fS = 20

# %%
# Change to twitter data dir
os.chdir('/home/wmkouw/Dropbox/Projects/ucopenhagen/seq-rumour/data/RumEval2019')

# %%
# Get folder paths
twitter_path = 'twitter-english/charliehebdo/'
threads = os.listdir(twitter_path)

# %%
# Get labels
with open('train-key.json') as f:
    train_key = json.load(f)
    
with open('dev-key.json') as f:
    dev_key = json.load(f)
    
label_keys = {**train_key['subtaskaenglish'], **dev_key['subtaskaenglish']}
train_key['subtaskaenglish']
# Out:
# {'501760642928635904': 'comment',
#  '500270212198174720': 'comment',
#  '524971210275565568': 'comment',
#  '552836882770690049': 'comment',
#  '500289931097296897': 'support',
#  '544293230649810944': 'comment',
#  '544283032732332032': 'comment',
#  '500406679176241153': 'comment',
#  '500300182844878848': 'comment',
#  '552811591683821568': 'comment',
#  '524938343180931073': 'comment',
#  '521360786409943041': 'deny',
#  '524946532416884736': 'comment',
#  '544347456238931968': 'comment',
#  '525020658972258305': 'query',
#  '552817834628501505': 'comment',
#  '524959078229880832': 'comment',
#  '553588165408473088': 'comment',
#  '544293748377518080': 'comment',
#  '553196346375954433': 'query',
#  '524957146656821249': 'comment',
#  '524992668301262848': 'deny',
#  '500294827351621632': 'comment',
#  '544307827070615553': 'support',
#  '524955418955902976': 'comment',
#  '553541495588802560': 'comment',
#  '500301494193627136': 'comment',
#  '525026551411519488': 'comment',
#  '553565149790224387': 'comment',
#  '544520601038098433': 'comment',
#  '544284034902528000': 'query',
#  '500319801344929795': 'support',
#  '524941900223381504': 'deny',
#  '552818473806491650': 'comment',
#  '553589038196981760': 'query',
#  '544452279441829888': 'comment',
#  '553595330009518080': 'comment',
#  '500304474616119296': 'comment',
#  '544519358232674305': 'comment',
#  '553550998497918976': 'comment',
#  '544349614393282561': 'comment',
#  '576801654118428672': 'comment',
#  '552815897425891328': 'comment',
#  '500319394325479424': 'comment',
#  '544991347304714240': 'comment',
#  '553589051044151296': 'support',
#  '524925730053181440': 'support',
#  '544355074672033792': 'deny',
#  '544285782639267840': 'comment',
#  '524969433308340224': 'comment',
#  '525000734992248832': 'deny',
#  '525031054537936897': 'comment',
#  '552812322075729920': 'deny',
#  '499456567990026240': 'query',
#  '544520807074918400': 'deny',
#  '499532946412687360': 'comment',
#  '544370150359572480': 'comment',
#  '544284571626635266': 'comment',
#  '552852233901965313': 'comment',
#  '499459462965362688': 'comment',
#  '553237817086967809': 'comment',
#  '524964692423630849': 'support',
#  '524937817924067328': 'comment',
#  '524939106367721472': 'support',
#  '553591557325336576': 'query',
#  '552844745647460352': 'comment',
#  '553578217387614208': 'comment',
#  '552814012791279617': 'comment',
#  '524961643688890368': 'comment',
#  '524991797630865408': 'comment',
#  '500281521841139712': 'support',
#  '544280076628414464': 'comment',
#  '553587741720854528': 'query',
#  '553552100417110017': 'comment',
#  '500287202124103680': 'comment',
#  '544300001568911360': 'comment',
#  '500371968831787009': 'comment',
#  '553551562732470272': 'comment',
#  '552834026948415488': 'comment',
#  '500307074589659137': 'comment',
#  '525060425184858112': 'support',
#  '553195335661912064': 'comment',
#  '500379240299122690': 'comment',
#  '553591773537513473': 'comment',
#  '544382892378714113': 'support',
#  '500321053197864961': 'deny',
#  '499368327530414080': 'comment',
#  '544320115647741952': 'support',
#  '500340654841798656': 'comment',
#  '544354628775600128': 'deny',
#  '544282786039726080': 'comment',
#  '544292185722851329': 'support',
#  '525061909968478208': 'support',
#  '499693411130429443': 'support',
#  '553584470264410113': 'comment',
#  '544518918912495616': 'comment',
#  '544530369312477184': 'comment',
#  '544478273238212608': 'comment',
#  '499596317413621760': 'comment',
#  '500308482676240384': 'comment',
#  '500295446578085889': 'comment',
#  '524946868887756801': 'comment',
#  '544392471007227904': 'support',
#  '500382019109810176': 'deny',
#  '524978385660153856': 'comment',
#  '553467311261503488': 'support',
#  '544314667795873792': 'comment',
#  '552814805456027648': 'comment',
#  '524970687803715584': 'comment',
#  '500303431928922113': 'comment',
#  '553213579672178689': 'query',
#  '524958146343624704': 'support',
#  '553535342049902592': 'comment',
#  '553550482925715458': 'comment',
#  '500288302100918272': 'comment',
#  '525036307173879808': 'comment',
#  '544302024352092162': 'comment',
#  '552842578539073537': 'comment',
#  '499369781846233088': 'comment',
#  '553485100932157440': 'support',
#  '500368855051804672': 'support',
#  '500288465355816960': 'comment',
#  '552834504520630274': 'comment',
#  '525043841490251776': 'comment',
#  '544276206728671232': 'comment',
#  '500311633458364416': 'comment',
#  '552997008483811328': 'comment',
#  '500348187656601600': 'query',
#  '553590107807428608': 'support',
#  '524956642454941696': 'comment',
#  '524966904885428226': 'support',
#  '576327374628917248': 'support',
#  '525008177683636224': 'comment',
#  '524966301085995008': 'support',
#  '552795069691232258': 'comment',
#  '552808137737383936': 'support',
#  '552943855021330432': 'comment',
#  '576513463738109954': 'deny',
#  '500386447158161408': 'query',
#  '553227312976908289': 'comment',
#  '499453449206239232': 'comment',
#  '553591766893727744': 'support',
#  '500301270532370433': 'comment',
#  '544284578068713473': 'comment',
#  '500429451323523073': 'comment',
#  '500488971080962048': 'deny',
#  '500387275767681024': 'comment',
#  '544374511194632192': 'support',
#  '544279084939767808': 'comment',
#  '524923588701614080': 'comment',
#  '524933596113801218': 'comment',
#  '524939593196793856': 'support',
#  '544517033644556288': 'support',
#  '544315887491117058': 'comment',
#  '500757739480842242': 'query',
#  '525057584416292867': 'comment',
#  '553508576422285312': 'comment',
#  '553184482241814530': 'deny',
#  '544333165612269569': 'comment',
#  '553549149787140096': 'comment',
#  '500406172155777025': 'support',
#  '552818286803443713': 'comment',
#  '544293447717650432': 'comment',
#  '553010394327834625': 'comment',
#  '544345919575949312': 'comment',
#  '524973155014946816': 'deny',
#  '544272691260178432': 'comment',
#  '500302378931716096': 'comment',
#  '544282548197916672': 'comment',
#  '499371743773863936': 'comment',
#  '524996775049191424': 'comment',
#  '576324695420743680': 'comment',
#  '524937325932212224': 'comment',
#  '544520557803225088': 'comment',
#  '553820631087988736': 'comment',
#  '500324150519808000': 'query',
#  '544292377897488384': 'comment',
#  '500274502652411904': 'comment',
#  '500405250755690496': 'comment',
#  '544521204401729536': 'query',
#  '544284075721494528': 'support',
#  '553471188530249730': 'comment',
#  '500318691909959681': 'deny',
#  '500384077481259008': 'support',
#  '553185239791857664': 'comment',
#  '524973649527193601': 'comment',
#  '544287503310528513': 'comment',
#  '544762521974890496': 'comment',
#  '544281262371119104': 'comment',
#  '544273878668050432': 'comment',
#  '544315302901608448': 'comment',
#  '500303952391331843': 'comment',
#  '544347670630785026': 'comment',
#  '500359435911716864': 'comment',
#  '524965546379739136': 'comment',
#  '544394097340207104': 'comment',
#  '499612545909415938': 'support',
#  '500415054559203329': 'support',
#  '524936215637000192': 'comment',
#  '552793785747660801': 'support',
#  '544282085763346432': 'comment',
#  '524961388532228098': 'support',
#  '524935485370929152': 'support',
#  '524979653027856385': 'comment',
#  '544279451760996352': 'comment',
#  '544399653332992000': 'comment',
#  '500298524953939969': 'comment',
#  '544288801926156289': 'support',
#  '524967669083414528': 'deny',
#  '500280396010229760': 'deny',
#  '500390676802961408': 'comment',
#  '500646220755251201': 'support',
#  '553546903842222080': 'comment',
#  '544290247710744576': 'comment',
#  '544480395585392641': 'support',
#  '544306389544624129': 'comment',
#  '553587104656404481': 'comment',
#  '500307435668930561': 'comment',
#  '524961635136704512': 'comment',
#  '553462961365581824': 'comment',
#  '500473967509909504': 'deny',
#  '544518602469441537': 'comment',
#  '521376439099465728': 'comment',
#  '500280663065772032': 'comment',
#  '500292755885531138': 'comment',
#  '500939702565105664': 'comment',
#  '553580075082203136': 'comment',
#  '553301531340972032': 'comment',
#  '552811900686176257': 'comment',
#  '500320646396518400': 'comment',
#  '552806767625641984': 'support',
#  '544331906469203968': 'comment',
#  '524930767810756608': 'comment',
#  '544299543899435008': 'comment',
#  '544310038613852160': 'comment',
#  '544354334348029952': 'comment',
#  '500386880635301889': 'comment',
#  '500285798089252865': 'comment',
#  '544279970483159040': 'comment',
#  '544294284015329280': 'deny',
#  '544282441091788801': 'deny',
#  '544352643242409984': 'comment',
#  '553503184174710784': 'support',
#  '544272759657078785': 'comment',
#  '500386770857758721': 'comment',
#  '553552734935601152': 'comment',
#  '544302363960684544': 'comment',
#  '553543369604210689': 'support',
#  '552816942193467396': 'comment',
#  '499460810704302080': 'query',
#  '500371547496796162': 'comment',
#  '524929224260714499': 'comment',
#  '544330751991230465': 'comment',
#  '525009203187171329': 'comment',
#  '500300308145528832': 'comment',
#  '553512763906334722': 'support',
#  '552808047643729920': 'support',
#  '525404874796961794': 'query',
#  '553531413459660800': 'support',
#  '553587974680875008': 'query',
#  '500378624113909760': 'comment',
#  '500444523039039488': 'comment',
#  '544486255921078272': 'comment',
#  '552810426422267904': 'comment',
#  '544497329920036865': 'deny',
#  '544517553427865601': 'comment',
#  '544297460936753152': 'comment',
#  '552989544589430784': 'deny',
#  '500297133841731585': 'comment',
#  '525032985738084352': 'comment',
#  '498440508256292864': 'comment',
#  '521371742942797825': 'comment',
#  '544309593916989440': 'comment',
#  '553587040886206466': 'comment',
#  '544293753130082305': 'support',
#  '553589786775412737': 'comment',
#  '500292093487886336': 'comment',
#  '500324845427916800': 'deny',
#  '544298655336136704': 'comment',
#  '544282252302381056': 'comment',
#  '500283973239865345': 'support',
#  '544290755624198144': 'comment',
#  '524961799641526273': 'comment',
#  '499688811300151297': 'comment',
#  '553557332261490688': 'support',
#  '500400890126155777': 'query',
#  '500285250791288832': 'comment',
#  '544301820865429506': 'support',
#  '499641023950512128': 'comment',
#  '544294473292079104': 'support',
#  '553590835850514433': 'support',
#  '544314234541469696': 'support',
#  '544288050810216448': 'comment',
#  '500294835559866371': 'comment',
#  '500365432902393859': 'comment',
#  '500379064146751490': 'comment',
#  '500377145349521411': 'support',
#  '544270541725511680': 'comment',
#  '524944416721862656': 'comment',
#  '500288271650684928': 'comment',
#  '500323321519800321': 'support',
#  '500478509366915072': 'comment',
#  '552814812363620352': 'comment',
#  '500313920301588480': 'comment',
#  '552835091714416640': 'comment',
#  '500327120770301952': 'support',
#  '553536816238710784': 'query',
#  '553490860369653761': 'comment',
#  '499612832363581440': 'comment',
#  '525006759807967232': 'deny',
#  '525007273832497154': 'comment',
#  '553534838880608256': 'support',
#  '524926310565814272': 'comment',
#  '544510279694823424': 'comment',
#  '544306124124860416': 'comment',
#  '525014151161081856': 'comment',
#  '544519563308580864': 'comment',
#  '524924021608284160': 'query',
#  '500315069142405120': 'comment',
#  '500405868244910081': 'query',
#  '524940069942358016': 'comment',
#  '544344866285576193': 'comment',
#  '500270734934282240': 'comment',
#  '544291860425232384': 'comment',
#  '500358464325947393': 'query',
#  '529687410611728384': 'comment',
#  '500478671451586560': 'support',
#  '544367318193930240': 'comment',
#  '525053884029763585': 'comment',
#  '500297800354377730': 'comment',
#  '544311848615432194': 'support',
#  '500319675797209088': 'support',
#  '525032806288601088': 'comment',
#  '553203171674181634': 'query',
#  '524941965012795393': 'comment',
#  '544342454938243072': 'comment',
#  '500460605686677504': 'comment',
#  '553577721939251201': 'deny',
#  '500395360125464576': 'comment',
#  '524971350881218560': 'comment',
#  '553575232867672064': 'comment',
#  '524930854335053824': 'deny',
#  '500303880820117504': 'support',
#  '553004470440058881': 'comment',
#  '553560292635189248': 'comment',
#  '544317774495875072': 'comment',
#  '500407281486663680': 'comment',
#  '553693040649334785': 'comment',
#  '525022456059547648': 'query',
#  '544414074906222593': 'deny',
#  '525030609757151232': 'support',
#  '524970408479850496': 'comment',
#  '544277972597755904': 'comment',
#  '500318081617367040': 'query',
#  '552816726144864258': 'comment',
#  '553550000584540160': 'comment',
#  '524996070972358656': 'comment',
#  '544341522213134336': 'comment',
#  '552806316855799808': 'comment',
#  '524928355016396800': 'comment',
#  '544452319904272385': 'support',
#  '552804602702475265': 'comment',
#  '544309574107693056': 'comment',
#  '554247300738854912': 'support',
#  '553486598328041472': 'comment',
#  '544345462564999169': 'support',
#  '552816063369326592': 'comment',
#  '525046262467293184': 'comment',
#  '553203187533230080': 'comment',
#  '500398105162821634': 'comment',
#  '500281543823458304': 'comment',
#  '544300909035937793': 'comment',
#  '544520376722927616': 'comment',
#  '544391921506852865': 'comment',
#  '552811563917123584': 'support',
#  '544349387741495296': 'comment',
#  '524960426132791296': 'comment',
#  '544511199702822913': 'support',
#  '553516393791238145': 'comment',
#  '499533154219474944': 'comment',
#  '544520377162952704': 'comment',
#  '544330788201050113': 'comment',
#  '524940813089144833': 'comment',
#  '553583385005006850': 'comment',
#  '500296225678045184': 'query',
#  '544534375577423872': 'comment',
#  '553589974369845248': 'comment',
#  '552806009157464064': 'comment',
#  '553589677433712640': 'support',
#  '500283406962663424': 'query',
#  '552811152456318976': 'comment',
#  '552813011338285056': 'support',
#  '500324120689930241': 'comment',
#  '553553247953514496': 'query',
#  '552805269441622017': 'comment',
#  '500299056934289408': 'support',
#  '524937953148403713': 'comment',
#  '524992704673890304': 'deny',
#  '544482722295844864': 'comment',
#  '499530130487017472': 'support',
#  '500347833774374912': 'deny',
#  '500291568361041920': 'comment',
#  '544331336266579969': 'query',
#  '500393320032370688': 'query',
#  '500285916494061568': 'comment',
#  '552812627378724864': 'comment',
#  '524946118774620161': 'comment',
#  '544290348525449216': 'support',
#  '553498348674875393': 'comment',
#  '544518122339049472': 'comment',
#  '524975860185825281': 'comment',
#  '500325414917505024': 'comment',
#  '553211195881426944': 'comment',
#  '544342839111327744': 'comment',
#  '544295967638302720': 'query',
#  '524932468437053440': 'query',
#  '524971862682767360': 'comment',
#  '524937639989092352': 'comment',
#  '544331338317565953': 'comment',
#  '500284767196430337': 'deny',
#  '525015279387299840': 'comment',
#  '552852018864218112': 'comment',
#  '553541692243316737': 'comment',
#  '500429697587871745': 'comment',
#  '552860931026604032': 'comment',
#  '525060851661668352': 'comment',
#  '544315537778413568': 'comment',
#  '521368022880378882': 'comment',
#  '525030173914431488': 'comment',
#  '544311985999867905': 'comment',
#  '553593015416008704': 'support',
#  '525026196451782656': 'comment',
#  '552984502063337472': 'deny',
#  '544391326712610817': 'comment',
#  '544311486118887425': 'comment',
#  '500290674957504513': 'comment',
#  '524926050351185920': 'deny',
#  '553008784692756480': 'comment',
#  '500286352605577218': 'comment',
#  '544277353900154880': 'comment',
#  '544294036463710209': 'comment',
#  '544408627512360961': 'query',
#  '544480133466574848': 'comment',
#  '544527922837479425': 'support',
#  '524932019248463872': 'comment',
#  '553520342111494145': 'support',
#  '553549946738446336': 'query',
#  '500404284219879424': 'support',
#  '544282348049956864': 'comment',
#  '524932994553769984': 'query',
#  '500344330046152705': 'comment',
#  '524973904969093120': 'comment',
#  '544407042111205377': 'comment',
#  '553473556345290752': 'query',
#  '544277505293561858': 'support',
#  '524959514995724288': 'deny',
#  '553225926436089856': 'deny',
#  '524971630678642688': 'comment',
#  '500297053990158336': 'comment',
#  '544336079877595136': 'support',
#  '544510576148238336': 'comment',
#  '576611747982897152': 'support',
#  '500360127522693120': 'support',
#  '552793899522355200': 'comment',
#  '544286591515373569': 'deny',
#  '498453364045529088': 'comment',
#  '544301597170233344': 'comment',
#  '544320586689048576': 'support',
#  '552807834078171136': 'comment',
#  '544320809276571650': 'support',
#  '553549946725875712': 'support',
#  '553203804628598784': 'comment',
#  '500413818368184321': 'support',
#  '553503274176110592': 'comment',
#  '524925775678816256': 'comment',
#  '544301354034794496': 'support',
#  '553577813056716800': 'deny',
#  '552792055122886656': 'deny',
#  '544324801188605952': 'support',
#  '553591360327282689': 'support',
#  '552874999522934784': 'comment',
#  '500338745359753216': 'comment',
#  '553538058440941568': 'support',
#  '553550518531141632': 'deny',
#  '525057571321688064': 'support',
#  '553559389102026752': 'comment',
#  '524970424246226945': 'comment',
#  '500391055259598849': 'comment',
#  '500323822730747904': 'comment',
#  '500397966071693312': 'comment',
#  '500312045334851585': 'comment',
#  '524949443607412737': 'support',
#  '500301215461548032': 'comment',
#  '525020749019770881': 'comment',
#  '553576559085240320': 'support',
#  '525038702607994880': 'comment',
#  '544331153994297344': 'comment',
#  '553540761632120832': 'comment',
#  '500316896299061248': 'query',
#  '553513937246097408': 'comment',
#  '499373428592611328': 'comment',
#  '524964193813155841': 'comment',
#  '552813563283509248': 'deny',
#  '525405160282288130': 'comment',
#  '552833028201144320': 'support',
#  '544298252078559232': 'comment',
#  '544391456140836864': 'comment',
#  '544292691928838144': 'comment',
#  '553538493738405888': 'comment',
#  '553199418032521216': 'support',
#  '500317982799982592': 'comment',
#  '544292129972170752': 'support',
#  '500320630156189697': 'support',
#  '544351912599240704': 'comment',
#  '544285415814225921': 'comment',
#  '544512676643500033': 'support',
#  '544518568633991170': 'support',
#  '500298745301729282': 'query',
#  '500380991035559937': 'comment',
#  '544315647182651392': 'comment',
#  '544315413862301697': 'deny',
#  '544286041155571712': 'support',
#  '499370097698291713': 'comment',
#  '544290947404943361': 'comment',
#  '544466740332462080': 'deny',
#  '553521113733824513': 'comment',
#  '553195879692517376': 'comment',
#  '553587585126117376': 'comment',
#  '524974129930592256': 'comment',
#  '552833887261691905': 'comment',
#  '544295112545538048': 'comment',
#  '544763686858944512': 'comment',
#  '553545342055354368': 'support',
#  '553511652587360256': 'support',
#  '552844369649098754': 'comment',
#  '499532679059374081': 'comment',
#  '544297640423587840': 'comment',
#  '500293402890469377': 'comment',
#  '544347330166530049': 'support',
#  '544334683090083840': 'comment',
#  '524962985995821057': 'comment',
#  '500442407830581248': 'comment',
#  '544279909796175873': 'support',
#  '552806751746396160': 'support',
#  '524975705206304769': 'support',
#  '524995354539085826': 'query',
#  '500342630145081344': 'comment',
#  '552838782710321152': 'comment',
#  '499689772928204800': 'deny',
#  '500409149977407489': 'comment',
#  '553469592488931328': 'support',
#  '544342707242414080': 'comment',
#  '544282429583003648': 'comment',
#  '500383587552985090': 'comment',
#  '577283431089901568': 'comment',
#  '544382368304214016': 'comment',
#  '529723719552618496': 'comment',
#  '553594432743018496': 'comment',
#  '553197339813220352': 'comment',
#  '500342822059646976': 'comment',
#  '521352738891132929': 'comment',
#  '552822387448631296': 'comment',
#  '544345616265261056': 'comment',
#  '544312720984915968': 'comment',
#  '500299923980824576': 'comment',
#  '552818611015131136': 'deny',
#  '524976661058826240': 'comment',
#  '500321405540786176': 'comment',
#  '553503876394262528': 'support',
#  '544278016235302912': 'comment',
#  '553486913970397186': 'comment',
#  '553587387889373186': 'deny',
#  '529696091638620160': 'comment',
#  '553501357156876290': 'support',
#  '525032614697385984': 'support',
#  '500312144421089281': 'query',
#  '553507222324801536': 'query',
#  '524930719077122048': 'comment',
#  '499689337370324992': 'deny',
#  '553588178687655936': 'support',
#  '500382101930143745': 'support',
#  '576327925869506560': 'query',
#  '500714300046974976': 'comment',
#  '500332078513520640': 'comment',
#  '553580917898231808': 'comment',
#  '553486812787007488': 'comment',
#  '544504969437540354': 'comment',
#  '552836375670562816': 'comment',
#  '553547724860456961': 'comment',
#  '553522878902468608': 'comment',
#  '524949253312217088': 'comment',
#  '521349366037356544': 'query',
#  '500281948233674753': 'comment',
#  '553111518230106112': 'comment',
#  '553518706681053184': 'support',
#  '500298800947142656': 'comment',
#  '553531861885259776': 'comment',
#  '544291071833157632': 'support',
#  '553507495604678658': 'comment',
#  '529748991849013248': 'query',
#  '525029987855122432': 'comment',
#  '544347461976727552': 'support',
#  '500282025543499777': 'support',
#  '500378835339476994': 'comment',
#  '524981938038534147': 'comment',
#  '544325077249302528': 'support',
#  '553184912258654208': 'comment',
#  '500355777878835200': 'comment',
#  '576279839205818368': 'support',
#  '500285527820890113': 'query',
#  '553591653404270592': 'support',
#  '525057102306222083': 'comment',
#  '529697981751373824': 'comment',
#  '544279768636465152': 'comment',
#  '500287363361546240': 'deny',
#  '500392059832770560': 'comment',
#  '553518472798683136': 'support',
#  '524974903683203072': 'comment',
#  '524934870469197824': 'comment',
#  '500402817065320448': 'comment',
#  '500285261813940224': 'comment',
#  '524926393394933760': 'deny',
#  '524925724499935232': 'support',
#  '553580571985580032': 'comment',
#  '544320325639364608': 'support',
#  '544375195612758016': 'comment',
#  '498465487635099648': 'comment',
#  '500284024162488321': 'comment',
#  '553507613900820481': 'comment',
#  '544483799174627329': 'query',
#  '499592983810158594': 'comment',
#  '553587034762534913': 'comment',
#  '544274483289157632': 'deny',
#  '544340424996184066': 'comment',
#  '553214220364685313': 'comment',
#  '524999052367527937': 'query',
#  '544379605818159104': 'support',
#  '544483162965807106': 'query',
#  '500282616289828864': 'comment',
#  '544309297480364032': 'support',
#  '500291010010701825': 'comment',
#  '544513062901141504': 'comment',
#  '500395581429526528': 'deny',
#  '553503409807327232': 'comment',
#  '553524499803815937': 'support',
#  '544306571350921216': 'comment',
#  '553091815218237440': 'comment',
#  '544480456478314496': 'comment',
#  '544369031214428160': 'support',
#  '552792862610694144': 'query',
#  '500289557624287234': 'query',
#  '500373096860487680': 'deny',
#  '552796160101220352': 'comment',
#  '544317955714994176': 'query',
#  '544272537341812736': 'support',
#  '500396139305517057': 'comment',
#  '576323996028952576': 'comment',
#  '529797259362177024': 'comment',
#  '553518923409547264': 'comment',
#  '552796934134845440': 'comment',
#  '544298946441392128': 'comment',
#  '544301863500541952': 'comment',
#  '525404621280641024': 'query',
#  '500356545730084864': 'query',
#  '524957420003803136': 'deny',
#  '500285361394708480': 'comment',
#  '544339122463453185': 'deny',
#  '500299469372420098': 'comment',
#  '553587860620996608': 'comment',
#  '500588486664409088': 'comment',
#  '524939588406878208': 'comment',
#  '544278581585907713': 'query',
#  '553535353790152705': 'query',
#  '544517545873530882': 'comment',
#  '498452460881870848': 'support',
#  '553590965307707393': 'support',
#  '552817939196678144': 'comment',
#  '500299687090335744': 'comment',
#  '524926131032850432': 'comment',
#  '499534240254803968': 'comment',
#  '500544598268063744': 'comment',
#  '553164985460068352': 'support',
#  '553542076999409664': 'comment',
#  '544771836672618496': 'comment',
#  '521366121484918785': 'deny',
#  '544294742260215809': 'comment',
#  '544363266244214784': 'deny',
#  '544477705316880384': 'comment',
#  '553201111159824384': 'support',
#  '553590957317566466': 'support',
#  '500279483732361216': 'comment',
#  '524966130700791808': 'comment',
#  '500294892606590977': 'comment',
#  '552808630022840320': 'query',
#  '553588188648714240': 'comment',
#  '553591626485215232': 'support',
#  '524995496944087040': 'comment',
#  '500547984526802944': 'comment',
#  '552791516360765440': 'comment',
#  '500317100704288768': 'comment',
#  '552848557766873090': 'comment',
#  '544395145529942016': 'comment',
#  '552808387415900160': 'comment',
#  '529698240405729281': 'comment',
#  '525062377713455104': 'support',
#  '544462330105712640': 'deny',
#  '553588210769883136': 'comment',
#  '544491151118860289': 'support',
#  '553115272031113216': 'comment',
#  '553526618720075776': 'support',
#  '544472273608908800': 'comment',
#  '500394517733068801': 'comment',
#  '552812425758912512': 'deny',
#  '510533977086500866': 'comment',
#  '500297826510057474': 'query',
#  '525059328685133824': 'deny',
#  '500479810939142144': 'comment',
#  '553574899302670337': 'comment',
#  '500341401583104000': 'comment',
#  '544278198150647809': 'query',
#  '576796432730071040': 'support',
#  '553224135334051840': 'comment',
#  '500322402656878592': 'comment',
#  '500285141370298368': 'comment',
#  '553535829017370625': 'support',
#  '553580837477056514': 'support',
#  '544403899679899648': 'comment',
#  '524966987169292288': 'query',
#  '524971253388816385': 'comment',
#  '499537282177978368': 'comment',
#  '544302134943297536': 'comment',
#  '544416983224430592': 'comment',
#  '544299161084895232': 'deny',
#  '521352186949672960': 'comment',
#  '544300933455548417': 'comment',
#  '544520444288589825': 'query',
#  '524953204224962560': 'support',
#  '544393459126521856': 'comment',
#  '544288681021145090': 'support',
#  '553563604117913600': 'comment',
#  '524928498771972096': 'support',
#  '576530311149932544': 'comment',
#  '499462501998665730': 'comment',
#  '500300300897751040': 'comment',
#  '524947416869388288': 'support',
#  '553587884263874561': 'comment',
#  '544493109963661312': 'comment',
#  '524959930928070656': 'comment',
#  '544295054723268608': 'support',
#  '525005729938554882': 'comment',
#  '500311345665810433': 'comment',
#  '544330294275235842': 'deny',
#  '544349391264296961': 'comment',
#  '500371565641756673': 'comment',
#  '552808156468768769': 'comment',
#  '544275371257233408': 'comment',
#  '544520042810200064': 'support',
#  '552805987053490179': 'comment',
#  '544321229360869376': 'comment',
#  '544516154145132544': 'comment',
#  '544299940764479490': 'support',
#  '500286793632071681': 'comment',
#  '500398642167947264': 'query',
#  '544346961097138176': 'comment',
#  '500327721747349506': 'comment',
#  '529695331387461632': 'comment',
#  '552804023389392896': 'comment',
#  '544358922904420352': 'support',
#  '500403075748618240': 'comment',
#  '554412391279374336': 'comment',
#  '553505371260588032': 'comment',
#  '499547493592743936': 'comment',
#  '544563172699426816': 'query',
#  '544518539936555008': 'support',
#  '524978305272135681': 'support',
#  '553481569675911168': 'comment',
#  '524956724311388161': 'support',
#  '524968348468412416': 'comment',
#  '500400188541140992': 'comment',
#  '544349254706155520': 'comment',
#  '500390996673585152': 'deny',
#  '544298113696292864': 'support',
#  '500306603233386496': 'comment',
#  '544307524770738176': 'comment',
#  '544297846233890816': 'comment',
#  '553199352060325888': 'support',
#  '500286470150967296': 'comment',
#  '552817356779433984': 'comment',
#  '529751327174586370': 'comment',
#  '553550346195574784': 'comment',
#  '552812482406780928': 'comment',
#  '524975119438200833': 'comment',
#  '524973750694182912': 'support',
#  '500659434558087168': 'comment',
#  '577258317942149120': 'support',
#  '500327896670830592': 'deny',
#  '500500740163383299': 'comment',
#  '500368286027354113': 'comment',
#  '500416260887166976': 'deny',
#  '544513191934713857': 'comment',
#  '500272785428860928': 'comment',
#  '544515538383564801': 'support',
#  '544280052175613952': 'support',
#  '553552395704082432': 'comment',
#  '500409234886889473': 'comment',
#  '552816676249403393': 'comment',
#  '529689790254698496': 'comment',
#  '499366666300846081': 'support',
#  '500350665315450881': 'support',
#  '544310853613281281': 'support',
#  '524950283244544002': 'comment',
#  '553551446164402176': 'support',
#  '500297973905895424': 'support',
#  '553479876632936448': 'comment',
#  '544405226451922944': 'comment',
#  '500331349421879297': 'support',
#  '544313623448137729': 'comment',
#  '553210433570881536': 'comment',
#  '544501395219808256': 'comment',
#  '500385894134992896': 'comment',
#  '500365775128248320': 'comment',
#  '524948114113703936': 'comment',
#  '544305745416581120': 'support',
#  '524928075981918209': 'comment',
#  '544311269533437952': 'comment',
#  '500301459469373440': 'comment',
#  '553545099905601536': 'support',
#  '524938029920948224': 'comment',
#  '524931324763992064': 'support',
#  '500379602435731456': 'support',
#  '525070724403564544': 'comment',
#  '500742011834470401': 'comment',
#  '524971471501021184': 'comment',
#  '553551580801536000': 'query',
#  '501667615350083584': 'query',
#  '553591098074226688': 'support',
#  '544341725830201344': 'comment',
#  '552833319747194882': 'comment',
#  '544764006368411648': 'comment',
#  '544507804829351937': 'comment',
#  '544517721862725632': 'comment',
#  '521353020484096001': 'support',
#  '500299463135858688': 'comment',
#  '544514420769296384': 'comment',
#  '524973660311154688': 'comment',
#  '544491585384505344': 'deny',
#  '529722000076718082': 'comment',
#  '552816523593916416': 'support',
#  '524925154611441664': 'comment',
#  '553549691129192448': 'comment',
#  '500393155066626048': 'query',
#  '553594257593106432': 'comment',
#  '525063388934967298': 'comment',
#  '524960409602650113': 'comment',
#  '500355191645171712': 'comment',
#  '500306749090324480': 'comment',
#  '552806438440292352': 'comment',
#  '500281916658958337': 'comment',
#  '524993079603130368': 'comment',
#  '553504747508879360': 'deny',
#  '552812407064899585': 'comment',
#  '500394049501544449': 'comment',
#  '553212962044149761': 'support',
#  '500283424477687808': 'comment',
#  '544347707981041664': 'comment',
#  '553587370822750210': 'deny',
#  '577282462788677634': 'comment',
#  '500356093801795585': 'deny',
#  '500347114975944705': 'support',
#  '544325103693987840': 'comment',
#  '524929656190148609': 'support',
#  '544300122998194177': 'comment',
#  '544278513264513024': 'deny',
#  '544290635013189632': 'comment',
#  '499773548202688512': 'query',
#  '525023805572648960': 'comment',
#  '524937374841987072': 'comment',
#  '544278855226122242': 'support',
#  '544319680194699264': 'deny',
#  '524948893633871872': 'comment',
#  '553555725084270593': 'comment',
#  '544301453717041152': 'support',
#  '576526712940310528': 'comment',
#  '544345812478988288': 'support',
#  '499538759076282368': 'comment',
#  '544277860555710464': 'support',
#  '500356297519165440': 'comment',
#  '524935683908333569': 'comment',
#  '524960036179968001': 'deny',
#  '544362143903010816': 'deny',
#  '498455687836758016': 'comment',
#  '552826072237346817': 'comment',
#  '552795831599120384': 'comment',
#  '544293179537625088': 'comment',
#  '529661580649459712': 'comment',
#  '552792023078825984': 'support',
#  '525049059321462784': 'comment',
#  '544500025016197121': 'comment',
#  '500327508706074624': 'comment',
#  '500393198603489280': 'comment',
#  '525070492395261953': 'support',
#  '544320300402638848': 'comment',
#  '544309751887429632': 'comment',
#  '524982445469622272': 'comment',
#  '524975028124016640': 'comment',
#  '544275135809998850': 'comment',
#  '544330709918183425': 'comment',
#  '553503523539652608': 'comment',
#  '553620764516429825': 'comment',
#  '529542083405955072': 'comment',
#  '524956679025487872': 'comment',
#  '524973778439528450': 'deny',
#  '553476490315431937': 'support',
#  '544336049330061315': 'deny',
#  '544333536086339584': 'query',
#  '500301957396193280': 'comment',
#  '553587467409162240': 'comment',
#  '544504183341064192': 'support',
#  '524969503499616256': 'comment',
#  '501806249264959488': 'comment',
#  '552792030225920000': 'comment',
#  '552807385496973312': 'comment',
#  '524972433984323584': 'comment',
#  '553538891228385280': 'comment',
#  '552816420074291200': 'support',
#  '553536361786277888': 'comment',
#  '500298472785182720': 'comment',
#  '500290809678536705': 'query',
#  '544521244021112832': 'comment',
#  '544421956360368129': 'comment',
#  '500280838710247424': 'support',
#  '499447049440743424': 'comment',
#  '544292469866000387': 'support',
#  '553521549395771392': 'comment',
#  '553011245737992193': 'comment',
#  '552806438629048320': 'comment',
#  '500295393301647360': 'support',
#  '525065680849481730': 'query',
#  '544348059501490177': 'comment',
#  '500406324644294657': 'support',
#  '500303419027247104': 'comment',
#  '553543653424386049': 'support',
#  '500286058664579072': 'support',
#  '553549440263675904': 'support',
#  '544514393372127232': 'support',
#  '500284023340818433': 'query',
#  '524929713014181890': 'support',
#  '499456140044824576': 'support',
#  '544271069146656768': 'support',
#  '525009978047078400': 'comment',
#  '544398446568820736': 'query',
#  '553588931707822080': 'comment',
#  '544515712640094209': 'comment',
#  '544291965513134080': 'support',
#  '499371059385098240': 'comment',
#  '553548128138584065': 'comment',
#  '544660449669967872': 'comment',
#  '500654216239915008': 'comment',
#  '544284471919652864': 'comment',
#  '544314448387645440': 'comment',
#  '500961800868098049': 'comment',
#  '500399589417963521': 'comment',
#  '544343251717611520': 'comment',
#  '529658952519540736': 'comment',
#  '521346721226711040': 'support',
#  '544346998975897600': 'comment',
#  '500319116776198144': 'comment',
#  '500285436527661056': 'comment',
#  '552837806574170113': 'comment',
#  '544519121405100033': 'support',
#  '544277459500556288': 'query',
#  '544310817521696769': 'support',
#  '500284990345981952': 'support',
#  '500371896295120896': 'support',
#  '553587013409325058': 'support',
#  '544397611172495360': 'comment',
#  '544513524438155264': 'support',
#  '544288116199407616': 'comment',
#  '500310617686040576': 'comment',
#  '524961093496885248': 'comment',
#  '524952352470495233': 'support',
#  '576435146632605696': 'support',
#  '544324400766799873': 'query',
#  '552827902065385476': 'comment',
#  '544337927132569601': 'comment',
#  '552850544797446144': 'support',
#  '524929568327888896': 'support',
#  '552808195710664704': 'comment',
#  '529694204361203713': 'comment',
#  '500317848536096768': 'comment',
#  '524926598576099328': 'support',
#  '521351041154289665': 'comment',
#  '544347250206310400': 'comment',
#  '544364547574726656': 'comment',
#  '544358564484378624': 'support',
#  '500392872856649728': 'comment',
#  '524962247563431936': 'support',
#  '500308366561124352': 'comment',
#  '500382426909392896': 'comment',
#  '500412019531849728': 'comment',
#  ...}

# %%
# Text array
tweet_id = []
thread_ix = [] 
response_ix = []
reply_ix = []
texts = []
created_date = []
created_datetime = []
labels = []

# Loop over threads
for t, thread in enumerate(threads):
    
    with open(twitter_path + thread + '/source-tweet/' + thread + '.json') as f:
        tweet = json.load(f)
        
        tweet_id.append(thread)
        thread_ix.append(t)
        reply_ix.append(0)
        texts.append(tweet['text'])
        created_date.append(dateutil.parser.parse(tweet['created_at']).date())
        created_datetime.append(dateutil.parser.parse(tweet['created_at']))  
        labels.append(label_keys[thread])
        
    replies = os.listdir(twitter_path + thread + '/replies/')
    for r, reply in enumerate(replies):
        
        with open(twitter_path + thread + '/replies/' + reply) as f:
            tweet = json.load(f)
                
            tweet_id.append(reply[:-5])
            thread_ix.append(t)
            reply_ix.append(r + 1)
            texts.append(tweet['text'])
            created_date.append(dateutil.parser.parse(tweet['created_at']).date())
            created_datetime.append(dateutil.parser.parse(tweet['created_at']))  
            labels.append(label_keys[reply[:-5]])

# %%
tweet
# Out:
# {'contributors': None,
#  'truncated': False,
#  'text': '@WSJ Well that guys a nut.',
#  'in_reply_to_status_id': 553576010898497536,
#  'id': 553576199268876288,
#  'favorite_count': 1,
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
#  'retweeted': False,
#  'coordinates': None,
#  'entities': {'symbols': [],
#   'user_mentions': [{'id': 3108351,
#     'indices': [0, 4],
#     'id_str': '3108351',
#     'screen_name': 'WSJ',
#     'name': 'Wall Street Journal'}],
#   'hashtags': [],
#   'urls': []},
#  'in_reply_to_screen_name': 'WSJ',
#  'id_str': '553576199268876288',
#  'retweet_count': 0,
#  'in_reply_to_user_id': 3108351,
#  'favorited': False,
#  'user': {'follow_request_sent': False,
#   'profile_use_background_image': True,
#   'profile_text_color': '333333',
#   'default_profile_image': False,
#   'id': 509601309,
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'verified': False,
#   'profile_location': None,
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1870365349/515897sy7tqv4xej_normal.jpg',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'entities': {'description': {'urls': []}},
#   'followers_count': 380,
#   'profile_sidebar_border_color': 'C0DEED',
#   'id_str': '509601309',
#   'profile_background_color': 'C0DEED',
#   'listed_count': 3,
#   'is_translation_enabled': False,
#   'utc_offset': None,
#   'statuses_count': 48240,
#   'description': "They laugh at me because I'm different. I laugh at them because they're all the same.",
#   'friends_count': 1994,
#   'location': '',
#   'profile_link_color': '0084B4',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1870365349/515897sy7tqv4xej_normal.jpg',
#   'following': False,
#   'geo_enabled': False,
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'name': 'Tom Croke',
#   'lang': 'en',
#   'profile_background_tile': False,
#   'favourites_count': 25285,
#   'screen_name': 'TomCroke3',
#   'notifications': False,
#   'url': None,
#   'created_at': 'Thu Mar 01 02:18:45 +0000 2012',
#   'contributors_enabled': False,
#   'time_zone': None,
#   'protected': False,
#   'default_profile': True,
#   'is_translator': False},
#  'geo': None,
#  'in_reply_to_user_id_str': '3108351',
#  'lang': 'en',
#  'created_at': 'Fri Jan 09 15:37:05 +0000 2015',
#  'in_reply_to_status_id_str': '553576010898497536',
#  'place': None}

# %%
# Convert to dataframe
data = pd.DataFrame({'id': tweet_id,
                     'thread_ix': thread_ix,
                     'reply_ix': reply_ix,
                     'text': texts,
                     'created_date': created_date,
                     'created_datetime': created_datetime,
                     'label': labels})

# %%
# write frame to csv
data.to_csv('./RumEval19.csv', sep='\t', encoding='utf-8', index=False)

# %%
data
# Out:
#      created_date          created_datetime                  id    label  \
# 0      2015-01-07 2015-01-07 11:28:49+00:00  552788945017516032  support
# 1      2015-01-07 2015-01-07 12:01:13+00:00  552797099138748416    query
# 2      2015-01-07 2015-01-07 11:40:59+00:00  552792005559189504  comment
# 3      2015-01-07 2015-01-07 11:58:32+00:00  552796424266854400  comment
# 4      2015-01-07 2015-01-07 11:52:24+00:00  552794881601859584  comment
# 5      2015-01-07 2015-01-07 11:29:22+00:00  552789083211460608  comment
# 6      2015-01-07 2015-01-07 11:31:54+00:00  552789720540119040  comment
# 7      2015-01-07 2015-01-07 12:04:05+00:00  552797821188206592  comment
# 8      2015-01-07 2015-01-07 11:59:36+00:00  552796692995907584  comment
# 9      2015-01-07 2015-01-07 11:33:15+00:00  552790062778548224  comment
# 10     2015-01-07 2015-01-07 11:51:16+00:00  552794594115870720  comment
# 11     2015-01-07 2015-01-07 12:08:02+00:00  552798814344839168  comment
# 12     2015-01-07 2015-01-07 11:54:51+00:00  552795498349101057  comment
# 13     2015-01-07 2015-01-07 11:34:47+00:00  552790446871945217  comment
# 14     2015-01-07 2015-01-07 11:34:33+00:00  552790386092294144  comment
# 15     2015-01-07 2015-01-07 11:45:36+00:00  552793167754715136  comment
# 16     2015-01-07 2015-01-07 11:29:37+00:00  552789147606581248  comment
# 17     2015-01-07 2015-01-07 11:48:16+00:00  552793839782862848  support
# 18     2015-01-07 2015-01-07 12:17:22+00:00  552801161128853504  comment
# 19     2015-01-07 2015-01-07 11:50:08+00:00  552794307632332800  comment
# 20     2015-01-07 2015-01-07 15:13:58+00:00  552845605786378241  comment
# 21     2015-01-07 2015-01-07 11:55:29+00:00  552795656235274240  comment
# 22     2015-01-07 2015-01-07 12:21:21+00:00  552802165488877568  comment
# 23     2015-01-07 2015-01-07 11:56:44+00:00  552795971999252481  comment
# 24     2015-01-07 2015-01-07 12:24:05+00:00  552802854453641216  comment
# 25     2015-01-07 2015-01-07 11:44:37+00:00  552792919325671425  comment
# 26     2015-01-07 2015-01-07 11:49:47+00:00  552794223263903744  comment
# 27     2015-01-07 2015-01-07 11:56:15+00:00  552795850783854592  comment
# 28     2015-01-09 2015-01-09 14:37:22+00:00  553561170637238272  support
# 29     2015-01-09 2015-01-09 14:38:55+00:00  553561561139535872    query
# ...           ...                       ...                 ...      ...
# 1134   2015-01-07 2015-01-07 13:53:15+00:00  552825292184514561     deny
# 1135   2015-01-07 2015-01-07 13:01:42+00:00  552812322075729920     deny
# 1136   2015-01-07 2015-01-07 12:44:43+00:00  552808047643729920  support
# 1137   2015-01-07 2015-01-07 13:00:52+00:00  552812110678196224  comment
# 1138   2015-01-07 2015-01-07 12:55:40+00:00  552810800164139008  comment
# 1139   2015-01-07 2015-01-07 19:12:00+00:00  552905510039465985  support
# 1140   2015-01-09 2015-01-09 12:56:40+00:00  553535829017370625  support
# 1141   2015-01-09 2015-01-09 13:59:30+00:00  553551642369753088  comment
# 1142   2015-01-09 2015-01-09 13:19:58+00:00  553541692243316737  comment
# 1143   2015-01-09 2015-01-09 12:59:19+00:00  553536495433580545  support
# 1144   2015-01-09 2015-01-09 12:58:47+00:00  553536361786277888  comment
# 1145   2015-01-09 2015-01-09 12:52:44+00:00  553534838880608256  support
# 1146   2015-01-09 2015-01-09 12:55:41+00:00  553535581586993152  support
# 1147   2015-01-09 2015-01-09 12:55:01+00:00  553535415073132544  comment
# 1148   2015-01-09 2015-01-09 12:54:47+00:00  553535353790152705    query
# 1149   2015-01-09 2015-01-09 13:09:41+00:00  553539103879200769  comment
# 1150   2015-01-09 2015-01-09 12:55:07+00:00  553535440821575682  comment
# 1151   2015-01-09 2015-01-09 15:36:20+00:00  553576010898497536  support
# 1152   2015-01-09 2015-01-09 15:48:38+00:00  553579107620237312  support
# 1153   2015-01-09 2015-01-09 15:43:08+00:00  553577721939251201     deny
# 1154   2015-01-09 2015-01-09 15:43:30+00:00  553577813056716800     deny
# 1155   2015-01-09 2015-01-09 15:38:31+00:00  553576559085240320  support
# 1156   2015-01-09 2015-01-09 15:41:01+00:00  553577189837258752  comment
# 1157   2015-01-09 2015-01-09 15:45:06+00:00  553578217387614208  comment
# 1158   2015-01-09 2015-01-09 15:44:12+00:00  553577990060539904  comment
# 1159   2015-01-09 2015-01-09 15:43:39+00:00  553577850461519872  comment
# 1160   2015-01-09 2015-01-09 15:39:35+00:00  553576829345628160  support
# 1161   2015-01-09 2015-01-09 15:43:20+00:00  553577770983645186  support
# 1162   2015-01-09 2015-01-09 15:40:48+00:00  553577135777255424  comment
# 1163   2015-01-09 2015-01-09 15:37:05+00:00  553576199268876288  comment
#
#       reply_ix                                               text  thread_ix
# 0            0  Appalled by the attack on Charlie Hebdo in Par...          0
# 1            1  @katherine1924 @Mumbobee @tnewtondunn @mehdirh...          0
# 2            2  @tnewtondunn @mehdirhasan  attacking religion ...          0
# 3            3  @m33ryg @tnewtondunn @mehdirhasan Can you supp...          0
# 4            4  @m33ryg @tnewtondunn @mehdirhasan You think pe...          0
# 5            5  @tnewtondunn You guys should put one of their ...          0
# 6            6  @mjhsinclair @tnewtondunn Sadly, since none of...          0
# 7            7  @UnbiasedF If you go into such facts it will b...          0
# 8            8  @m33ryg @Mumbobee @tnewtondunn @mehdirhasan Th...          0
# 9            9  @tnewtondunn solidarity is key - we can't be m...          0
# 10          10  @Mumbobee @tnewtondunn @mehdirhasan  if free s...          0
# 11          11  @Cavelloman1 @mjhsinclair @tnewtondunn @Victor...          0
# 12          12  @UnbiasedF @tnewtondunn @mehdirhasan of course...          0
# 13          13    @tnewtondunn @theuneasyreaper poor people :((((          0
# 14          14                @tnewtondunn @theuneasyreaper rip x          0
# 15          15                      @tnewtondunn #i'llridewithyou          0
# 16          16  @tnewtondunn Important moment. Other papers co...          0
# 17          17  @tnewtondunn Freedom of speech is something to...          0
# 18          18  @Olenkafrenkiel @Cavelloman1 @mjhsinclair @tne...          0
# 19          19  @m33ryg @tnewtondunn @mehdirhasan Of course it...          0
# 20          20  @m33ryg @katherine1924 @Mumbobee @tnewtondunn ...          0
# 21          21  @m33ryg @Mumbobee @tnewtondunn @mehdirhasan Yo...          0
# 22          22  @m33ryg @katherine1924 @tnewtondunn @mehdirhas...          0
# 23          23  @katherine1924 @Mumbobee @tnewtondunn @mehdirh...          0
# 24          24  @Mumbobee this is what ppl are not understandi...          0
# 25          25  @tnewtondunn @toadmeister \nWhen will EU wake up?          0
# 26          26  @mjhsinclair @Olenkafrenkiel @tnewtondunn No.....          0
# 27          27  @m33ryg @tnewtondunn @mehdirhasan "Facts about...          0
# 28           0  BREAKING: Police order all shops closed in fam...          1
# 29           1  The Marais? RT @AP BREAKING: Police order all ...          1
# ...        ...                                                ...        ...
# 1134         7  @USATODAY @AP\n* US Citizens!!\n2015:Fbruary 5...         74
# 1135         8  @USATODAY @12News @AP This is not about politi...         74
# 1136         9  “@USATODAY: 12 now confirmed dead in #CharlieH...         74
# 1137        10  @USATODAY @usmanmanzoor @AP Very sad.\n\nAmazi...         74
# 1138        11  @seb746138 @USATODAY @AP seb746138 SEE that -&...         74
# 1139        12  @USATODAY @AP Why Muslims killed Non-muslims ?...         74
# 1140         0  #BREAKING - At least five hostages in Paris ko...         75
# 1141         1  @FRANCE24 is this all part of a plan .. a spre...         75
# 1142         2  @FRANCE24 @HarrietBaldwin It's time 4 West 2 m...         75
# 1143         3  RT @FRANCE24 #BREAKING - At least five hostage...         75
# 1144         4  “@FRANCE24: #BREAKING - At least five hostages...         75
# 1145         0  #BREAKING Gunman in policewoman killing suspec...         76
# 1146         1  “@AFP: #BREAKING Gunman in policewoman killing...         76
# 1147         2       @AFP 5 hostages (including women and childs)         76
# 1148         3                        @AFP give the source please         76
# 1149         4  Good Lord - this crisis in France is spreading...         76
# 1150         5  #Vincennes #Montrouge RT “@AFP: #BREAKING Gunm...         76
# 1151         0  Breaking: Gunman at Paris store threatens to k...         77
# 1152         1  “@WSJ: Breaking: Gunman at Paris store threate...         77
# 1153         2  @WSJ how would they know if they are harmed or...         77
# 1154         3  “@WSJ: Breaking: Gunman at Paris store threate...         77
# 1155         4  @WSJ \n#StopKillingInnocentPeople\n#FreePalest...         77
# 1156         5  @WSJ seems it would behoove police to kill tha...         77
# 1157         6  Omg “@WSJ: Breaking: Gunman at Paris store thr...         77
# 1158         7  @duesouth22 the terrorist had meeting with pré...         77
# 1159         8  “@WSJ: Breaking: Gunman at Paris store threate...         77
# 1160         9  “@WSJ: Breaking: Gunman at Paris store threate...         77
# 1161        10  @WSJ @slone #Gunman had meeting with former pr...         77
# 1162        11  @WSJ Before attack, French began ceding contro...         77
# 1163        12                         @WSJ Well that guys a nut.         77
#
# [1164 rows x 7 columns]

# %% [markdown]
# # Twitter word embeddings

# %%
os.chdir('/home/wmkouw/Dropbox/Projects/ucopenhagen/seq-rumour/data/word2vec-twitter')

# %%
# change 'xrange' in word2vecReader to 'range'
exec(open("repl.py").read())
# Out:
# Loading the model, this can take some time...
# The vocabulary size is: 3039345

# %%
tt = TweetTokenizer()

num_tweets = len(data)

wemb = np.zeros((num_tweets, 400))
for n in range(num_tweets):
    
    aa = tt.tokenize(data['text'][n])
    
    ct = 0
    for a in aa:
        
        try:
            wemb[n, :] += model.__getitem__(a)
            ct += 1
        except:
            print('.', end='')
    
    # Average embeddings
    wemb[n, :] /= ct
    
# Add word embeddings to dataframe
data = data.assign(embedding=wemb.tolist())

# Write embbeding array separately
np.save('rumeval19.npy', wemb)
# Out:
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# /home/wmkouw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in true_divide
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
